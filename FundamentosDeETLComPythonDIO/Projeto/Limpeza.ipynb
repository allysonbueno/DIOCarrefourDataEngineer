# %%
import pandas as pd

# %%
# df = dataframe
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [raw]
# schema.validate(df)

# %%
# mostra da linha 1 até 3
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
# mostra a linha 10 e 40 apenas
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.ocorrencia_uf.is_unique
# Out:
# False

# %%
df.ocorrencia_cidade.is_unique
# Out:
# False

# %%
# indexação
df.set_index('codigo_ocorrencia', inplace=True)

# %%
# df.head()

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %% [raw]
# df.head()

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
# df.head(1)

# %% [raw]
# # alterar uma linha inteira
# df.loc[1] = 20

# %%
# df.head(2)

# %%
# fazer backup antes de alterar uma coluna inteira
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
# alterar dado de uma coluna em todas as linhas
df.loc[:,'total_recomendacoes'] = 10

# %%
# df

# %%
# pesquisando occorencia uf que é igual a SP e mudando classificação
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
# df.loc[df.ocorrencia_uf == 'SP']

# %% [raw]
# df

# %% [markdown]
# INICIO LIMPEZA
#
# ocorrencia_uf tem informações como:
# **
# ###!
# ####
# ****
# *****
#
# ocorrencia_hora:
# NULL

# %%
# df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA


df.replace(['**','***','****','###!','####','NULL'], pd.NA, inplace=True)
# inplace faz o tratamento dentro do Dataframe

# %%
df.isna().sum()
# mesma coisa com df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2291
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2291
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2291
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
# df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)
df.drop(['ocorrencia_hora'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2291
# ocorrencia_dia                 0
# total_recomendacoes            0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# não recomendavel usar df.dropna() pois ele deleta a linha inteira mesmo que contenha apenas um valor NA

# dropa apenas a linha que contem ocorrencia_uf = NA
df.dropna(subset=['ocorrencia_uf'])
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                 40211                INCIDENTE      RIO DE JANEIRO
# 1                 40349                INCIDENTE               BELÉM
# 2                 40351                INCIDENTE      RIO DE JANEIRO
# 3                 39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                 40324                INCIDENTE             PELOTAS
# ...                 ...                      ...                 ...
# 6109              80245                INCIDENTE              RECIFE
# 6110              80247                INCIDENTE         PORTO VELHO
# 6111              80251                INCIDENTE               BELÉM
# 6112              80257                 ACIDENTE          DOM AQUINO
# 6113              80259                    GRAVE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                 40211                INCIDENTE      RIO DE JANEIRO
# 1                 40349                INCIDENTE               BELÉM
# 2                 40351                INCIDENTE      RIO DE JANEIRO
# 3                 39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                 40324                INCIDENTE             PELOTAS
# ...                 ...                      ...                 ...
# 6109              80245                INCIDENTE              RECIFE
# 6110              80247                INCIDENTE         PORTO VELHO
# 6111              80251                INCIDENTE               BELÉM
# 6112              80257                 ACIDENTE          DOM AQUINO
# 6113              80259                    GRAVE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.dropna(subset=['ocorrencia_hora'])
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                 40211                INCIDENTE      RIO DE JANEIRO
# 1                 40349                INCIDENTE               BELÉM
# 2                 40351                INCIDENTE      RIO DE JANEIRO
# 3                 39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                 40324                INCIDENTE             PELOTAS
# ...                 ...                      ...                 ...
# 6109              80245                INCIDENTE              RECIFE
# 6110              80247                INCIDENTE         PORTO VELHO
# 6111              80251                INCIDENTE               BELÉM
# 6112              80257                 ACIDENTE          DOM AQUINO
# 6113              80259                    GRAVE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
null_columns=df.columns[df.isnull().any()]
# df.loc(isnull('ocorrencia_hora'))

# %%
df[null_columns].isnull().sum()
# Out:
# ocorrencia_hora           1
# total_recomendacoes    6114
# dtype: int64

# %%
print(df[df.isnull().any(axis=1)][null_columns].head())
# Out:
#   ocorrencia_hora total_recomendacoes
# 0        12:00:00                <NA>
# 1        11:05:00                <NA>
# 2        03:00:00                <NA>
# 3        17:30:00                <NA>
# 4        19:25:00                <NA>

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2291
# ocorrencia_dia                 0
# total_recomendacoes            0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...
