# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['**','***','****','*****','###!','####','NULL']
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_qualquer": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, 
                pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), 
                nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
# localizar pelo indice
df.iloc[-1]
# Out:
# codigo_ocorrencia                         80259
# codigo_ocorrencia2                        80259
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                      CAMPINAS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBKP
# ocorrencia_dia              2021-08-18 00:00:00
# ocorrencia_hora                        12:45:00
# total_recomendacoes                           0
# Name: 6113, dtype: object

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6109            RECIFE            PE                 SBRF     2021-08-15
# 6110       PORTO VELHO            RO                 SBPV     2021-08-16
# 6111             BELÉM            PA                 SBBE     2021-08-17
# 6112        DOM AQUINO            MT                  NaN     2021-08-18
# 6113          CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 6109        15:05:00                    0
# ...

# %%
df.iloc[10:12]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11         SÃO PAULO            SP                 SBMT     2010-01-10
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8

# %%
# : significa qualquer ou todas as linhas
df.loc[:, 'ocorrencia_uf']
# mesma coisa que usar
# df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
# df.isna().sum() ou
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# df.loc[df.ocorrencia_uf.isnull()]
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
# 5855              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 5855      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0
# 5855        11:00:00                    0

# %%
filtro = df.ocorrencia_aerodromo.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6092              80236               80236                 ACIDENTE
# 6093              80227               80227                 ACIDENTE
# 6096              80229               80229                INCIDENTE
# 6099              80233               80233                 ACIDENTE
# 6112              80257               80257                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
filtro = df.ocorrencia_hora.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4102              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4102           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4102             NaN                    0

# %%
# print(df[df.isnull().any(axis=1)][null_columns].head())
df.count()
# Out:
# codigo_ocorrencia           6114
# codigo_ocorrencia2          6114
# ocorrencia_classificacao    6114
# ocorrencia_cidade           6114
# ocorrencia_uf               6112
# ocorrencia_aerodromo        3658
# ocorrencia_dia              6114
# ocorrencia_hora             6113
# total_recomendacoes         6114
# dtype: int64

# %%
# ocorrencias com mais de 10 recomendações
filtro = df.total_recomendacoes > 10
df.loc[filtro, 'ocorrencia_cidade']
# Out:
# 63                 SÃO PAULO
# 326           RIO DE JANEIRO
# 530                SÃO PAULO
# 727                 ITÁPOLIS
# 872                   RECIFE
# 884     SÃO JOSÉ DOS PINHAIS
# 1062              UBERLÂNDIA
# 1972                BRASÍLIA
# 2797                  SANTOS
# 3932                 VITÓRIA
# Name: ocorrencia_cidade, dtype: object

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro,['ocorrencia_cidade','total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3932               VITÓRIA                   12

# %%
#ocorrencias cuja classificacao == INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6090              80221               80221          INCIDENTE GRAVE
# 6095              80228               80228          INCIDENTE GRAVE
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrencias cuja classificacao == INCIDENTE GRAVE e estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5949              80056               80056          INCIDENTE GRAVE
# 6000              80114               80114          INCIDENTE GRAVE
# 6007              80124               80124          INCIDENTE GRAVE
# 6081              80200               80200          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrencias cuja classificacao == INCIDENTE GRAVE 'OU' estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrencias cuja (classificacao == INCIDENTE GRAVE 'OU' classificacao == INCIDENTE) 'E' estado == SP
# filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE') 
# usando IN 
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE','INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 6084              80234               80234                INCIDENTE
# 6085              80208               80208                INCIDENTE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# todas as ocorrencias cuja cidade começa com letra C
# filtro = df.ocorrencia_cidade.str[0] == 'C'

# todas as ocorrencias cuja cidade termina com letra A
# filtro = df.ocorrencia_cidade.str[-1] == 'A'

# todas as ocorrencias cuja cidade termina com letras MA
filtro = df.ocorrencia_cidade.str[-2:] == 'BA'

df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 26                39847               39847                INCIDENTE
# 29                39709               39709          INCIDENTE GRAVE
# 62                39930               39930          INCIDENTE GRAVE
# 67                39988               39988                INCIDENTE
# 74                40296               40296                INCIDENTE
# ...                 ...                 ...                      ...
# 6030              80141               80141                INCIDENTE
# 6031              80142               80142                INCIDENTE
# 6070              80191               80191                INCIDENTE
# 6088              80220               80220                INCIDENTE
# 6094              80225               80225                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencia de cidade que contem os caracteres 'BA'
filtro = df.ocorrencia_cidade.str.contains('BA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 26                39847               39847                INCIDENTE
# 29                39709               39709          INCIDENTE GRAVE
# 62                39930               39930          INCIDENTE GRAVE
# 67                39988               39988                INCIDENTE
# 74                40296               40296                INCIDENTE
# ...                 ...                 ...                      ...
# 6065              80222               80222                INCIDENTE
# 6070              80191               80191                INCIDENTE
# 6080              80199               80199                INCIDENTE
# 6088              80220               80220                INCIDENTE
# 6094              80225               80225                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencia de cidade que contem os caracteres 'BA' OU 'AL'
filtro = df.ocorrencia_cidade.str.contains('BA|AL')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 17                39810               39810                INCIDENTE
# 26                39847               39847                INCIDENTE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6065              80222               80222                INCIDENTE
# 6070              80191               80191                INCIDENTE
# 6080              80199               80199                INCIDENTE
# 6088              80220               80220                INCIDENTE
# 6094              80225               80225                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
# ocorrencias do ano de 2015
# filtro = df.ocorrencia_dia.dt.year == 2015
# ocorrencias do mês 08
# filtro = df.ocorrencia_dia.dt.month == 8

# ocorrencias do dia 06/08/2015
filtro = (df.ocorrencia_dia.dt.month == 8) & (df.ocorrencia_dia.dt.year == 2015) & (df.ocorrencia_dia.dt.day == 6)

df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3286              53428               53428                 ACIDENTE
# 3287              53440               53440                INCIDENTE
# 3288              53441               53441                INCIDENTE
# 3289              53442               53442                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3286           GOIÂNIA            GO                 SBNV     2015-08-06
# 3287        UBERLÂNDIA            MG                 SBUL     2015-08-06
# 3288            ILHÉUS            BA                 SBIL     2015-08-06
# 3289          SANTARÉM            PA                 SBSN     2015-08-06
#
#      ocorrencia_hora  total_recomendacoes
# 3286        11:35:00                    1
# 3287        18:48:00                    0
# 3288        18:30:00                    0
# 3289        14:19:00                    0

# %%
# ocorrencias do dia 03 ao dia 08 de 08/2015
filtroDia = (df.ocorrencia_dia.dt.day >= 3) & (df.ocorrencia_dia.dt.day <= 8)
filtroMes = df.ocorrencia_dia.dt.month == 8
filtroAno = df.ocorrencia_dia.dt.year == 2015
df.loc[filtroDia & filtroMes & filtroAno]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3286              53428               53428                 ACIDENTE
# 3287              53440               53440                INCIDENTE
# 3288              53441               53441                INCIDENTE
# 3289              53442               53442                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3286           GOIÂNIA            GO                 SBNV     2015-08-06
# 3287        UBERLÂNDIA            MG                 SBUL     2015-08-06
# 3288            ILHÉUS            BA                 SBIL     2015-08-06
# 3289          SANTARÉM            PA                 SBSN     2015-08-06
#
#      ocorrencia_hora  total_recomendacoes
# 3286        11:35:00                    1
# 3287        18:48:00                    0
# 3288        18:30:00                    0
# 3289        14:19:00                    0

# %%
# criar coluna com data e hora juntos
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
# ocorrencias do dia 06/08/2015 com a coluna nova criada acima
filtroDia = df.ocorrencia_dia_hora.dt.day == 6
filtroMes = df.ocorrencia_dia_hora.dt.month == 8
filtroAno = df.ocorrencia_dia_hora.dt.year == 2015

df.loc[filtroDia & filtroMes & filtroAno]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3286              53428               53428                 ACIDENTE
# 3287              53440               53440                INCIDENTE
# 3288              53441               53441                INCIDENTE
# 3289              53442               53442                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3286           GOIÂNIA            GO                 SBNV     2015-08-06
# 3287        UBERLÂNDIA            MG                 SBUL     2015-08-06
# 3288            ILHÉUS            BA                 SBIL     2015-08-06
# 3289          SANTARÉM            PA                 SBSN     2015-08-06
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 3286        11:35:00                    1 2015-08-06 11:35:00
# 3287        18:48:00                    0 2015-08-06 18:48:00
# 3288        18:30:00                    0 2015-08-06 18:30:00
# ...

# %%
# ocorrencias do dia 06/08/2015 das 14 horas até às 19 horas com a coluna nova criada acima
filtroInicial = df.ocorrencia_dia_hora >= '2015-08-06 14:00:00'
filtroFinal = df.ocorrencia_dia_hora <= '2015-08-06 19:00:00'
df.loc[filtroInicial & filtroFinal]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3287              53440               53440                INCIDENTE
# 3288              53441               53441                INCIDENTE
# 3289              53442               53442                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3287        UBERLÂNDIA            MG                 SBUL     2015-08-06
# 3288            ILHÉUS            BA                 SBIL     2015-08-06
# 3289          SANTARÉM            PA                 SBSN     2015-08-06
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 3287        18:48:00                    0 2015-08-06 18:48:00
# 3288        18:30:00                    0 2015-08-06 18:30:00
# 3289        14:19:00                    0 2015-08-06 14:19:00

# %%
# ocorrencias do ano de 2015 e mês 03
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro1 & filtro2]
df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3088              53183               53183                 ACIDENTE
# 3089              53120               53120                 ACIDENTE
# 3090              53109               53109                 ACIDENTE
# 3091              53112               53112                 ACIDENTE
# 3092              53152               53152          INCIDENTE GRAVE
# 3093              53167               53167                INCIDENTE
# 3094              53596               53596                INCIDENTE
# 3095              53149               53149                 ACIDENTE
# 3096              53148               53148                 ACIDENTE
# 3097              53153               53153                INCIDENTE
# 3098              53154               53154                INCIDENTE
# 3099              53238               53238                INCIDENTE
# 3100              53189               53189                INCIDENTE
# ...

# %%
# observar que o ocorrencia_aerodromo contem informacoes nulas e não se pode agrupar por ele
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
# select count de df201503 agrupando por codigo_ocorrencia
# df201503.groupby(['codigo_ocorrencia']).count()

# df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# contando por uma coluna que tem NULO é errado ==> df201503.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
# ordenando descrescente
df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
# ocorrencias de 2010 da regiao sudeste
filtro1 = df.ocorrencia_dia.dt.year == 2010
filtro2 = df.ocorrencia_uf.isin(['SP','MG','ES','RJ'])
dfsudeste2010 = df.loc[filtro1 & filtro2]
dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# ...

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
dfsudeste2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
# ordenacao por classificacao da ocorrencia e uf
# # dfsudeste2010.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# dfsudeste2010.groupby(['ocorrencia_uf','ocorrencia_classificacao']).size()

# %%
# ordenacao por classificacao da ocorrencia agrupando por por cidades
# dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)

# por uma unica cidade e com recomendacoes maior que 0
filtro1 = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
filtro2 = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 119              40190               40190                INCIDENTE
# 274              41750               41750                 ACIDENTE
# 326              42250               42250                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 119    RIO DE JANEIRO            RJ                 SBGL     2010-04-06
# 274    RIO DE JANEIRO            RJ                 SBJR     2010-07-12
# 326    RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 119        02:35:00                    3 2010-04-06 02:35:00
# 274        19:53:00                    3 2010-07-12 19:53:00
# 326        12:26:00                   19 2010-08-12 12:26:00

# %%
# total de recomendacoes por aerodromo da cidade RJ
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 0

# %%
# total de recomendacoes por cidade 
# dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()

# total de recomendacoes por cidade  e que total_recomendacoes é maior que zero
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# JUNDIAÍ                   7
# RESENDE                   8
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# SÃO PAULO                41
# Name: total_recomendacoes, dtype: int64

# %%
# total de ocorrencia_aerodromo
# dfsudeste2010.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()

# total de ocorrencia_aerodromo e que total_recomendacoes seja maior que zero
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_aerodromo
# SBPR     1
# SDOI     1
# SBGL     3
# SBJR     3
# SBJD     7
# SBBP     9
# SBRJ    19
# SBMT    27
# NaN     45
# Name: total_recomendacoes, dtype: int64

# %%
# agrupando por cidades, por mes e somando total recomendacoes
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# BELO HORIZONTE         2                  1
#                        3                  1
# BOITUVA                7                  1
# BOM JESUS DO GALHO     12                 1
# BRAGANÇA PAULISTA      11                 9
# CAMANDUCAIA            7                  9
# IPERÓ                  1                  3
# ITANHAÉM               9                  1
# JUNDIAÍ                5                  5
#                        6                  2
# NOVO HORIZONTE         7                  3
# RESENDE                4                  8
# RIO DE JANEIRO         4                  3
#                        7                  3
#                        8                 19
# SÃO BERNARDO DO CAMPO  1                  2
# SÃO PAULO              1                  8
#                        2                 14
#                        6                  2
#                        11                 6
# ...

# %%
filtro1 = dfsudeste2010.total_recomendacoes > 0
filtro2 = dfsudeste2010.ocorrencia_cidade == 'SÃO PAULO'
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11               40069               40069                 ACIDENTE
# 58               39275               39275                 ACIDENTE
# 63               39992               39992                 ACIDENTE
# 219              41411               41411          INCIDENTE GRAVE
# 469              43450               43450                 ACIDENTE
# 530              43471               43471                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 11          SÃO PAULO            SP                 SBMT     2010-01-10
# 58          SÃO PAULO            SP                  NaN     2010-02-10
# 63          SÃO PAULO            SP                 SBMT     2010-02-17
# 219         SÃO PAULO            SP                 SBMT     2010-06-08
# 469         SÃO PAULO            SP                 SBMT     2010-11-04
# ...
